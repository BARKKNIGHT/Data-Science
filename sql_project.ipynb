# %%
import pymysql.cursors

# %%
def get_connection():
    connection = pymysql.connect(host='localhost',
                                 user='root',
                                 password='1234',
                                 database='hr',
                                 charset='utf8mb4',
                                 cursorclass=pymysql.cursors.DictCursor)
    return connection

# %% [markdown]
# # 1. Retrieve all details of employees.

# %%
connection = get_connection()
with connection:
    with connection.cursor() as cursor:
        sql = "Select * from employees"
        cursor.execute(sql)
        data = cursor.fetchall()
        print(data)
# Out:
# [{'employee_id': 100, 'first_name': 'Steven', 'last_name': 'King', 'email': 'SKING', 'phone_number': '515.123.4567', 'hire_date': datetime.date(1987, 6, 17), 'job_id': 'AD_PRES', 'salary': 24000.0, 'commission_pct': None, 'manager_id': None, 'department_id': 90}, {'employee_id': 101, 'first_name': 'Neena', 'last_name': 'Kochhar', 'email': 'NKOCHHAR', 'phone_number': '515.123.4568', 'hire_date': datetime.date(1989, 9, 21), 'job_id': 'AD_VP', 'salary': 17000.0, 'commission_pct': None, 'manager_id': 100, 'department_id': 90}, {'employee_id': 102, 'first_name': 'Lex', 'last_name': 'De Haan', 'email': 'LDEHAAN', 'phone_number': '515.123.4569', 'hire_date': datetime.date(1993, 1, 13), 'job_id': 'AD_VP', 'salary': 17000.0, 'commission_pct': None, 'manager_id': 100, 'department_id': 90}, {'employee_id': 103, 'first_name': 'Alexander', 'last_name': 'Hunold', 'email': 'AHUNOLD', 'phone_number': '590.423.4567', 'hire_date': datetime.date(1990, 1, 3), 'job_id': 'IT_PROG', 'salary': 9000.0, 'commission_pct': None, 'manager_id': 102, 'department_id': 60}, {'employee_id': 104, 'first_name': 'Bruce', 'last_name': 'Ernst', 'email': 'BERNST', 'phone_number': '590.423.4568', 'hire_date': datetime.date(1991, 5, 21), 'job_id': 'IT_PROG', 'salary': 6000.0, 'commission_pct': None, 'manager_id': 103, 'department_id': 60}, {'employee_id': 105, 'first_name': 'David', 'last_name': 'Austin', 'email': 'DAUSTIN', 'phone_number': '590.423.4569', 'hire_date': datetime.date(1997, 6, 25), 'job_id': 'IT_PROG', 'salary': 4800.0, 'commission_pct': None, 'manager_id': 103, 'department_id': 60}, {'employee_id': 106, 'first_name': 'Valli', 'last_name': 'Pataballa', 'email': 'VPATABAL', 'phone_number': '590.423.4560', 'hire_date': datetime.date(1998, 2, 5), 'job_id': 'IT_PROG', 'salary': 4800.0, 'commission_pct': None, 'manager_id': 103, 'department_id': 60}, {'employee_id': 107, 'first_name': 'Diana', 'last_name': 'Lorentz', 'email': 'DLORENTZ', 'phone_number': '590.423.5567', 'hire_date': datetime.date(1999, 2, 7), 'job_id': 'IT_PROG', 'salary': 4200.0, 'commission_pct': None, 'manager_id': 103, 'department_id': 60}, {'employee_id': 108, 'first_name': 'Nancy', 'last_name': 'Greenberg', 'email': 'NGREENBE', 'phone_number': '515.124.4569', 'hire_date': datetime.date(1994, 8, 17), 'job_id': 'FI_MGR', 'salary': 12000.0, 'commission_pct': None, 'manager_id': 101, 'department_id': 100}, {'employee_id': 109, 'first_name': 'Daniel', 'last_name': 'Faviet', 'email': 'DFAVIET', 'phone_number': '515.124.4169', 'hire_date': datetime.date(1994, 8, 16), 'job_id': 'FI_ACCOUNT', 'salary': 9000.0, 'commission_pct': None, 'manager_id': 108, 'department_id': 100}, {'employee_id': 110, 'first_name': 'John', 'last_name': 'Chen', 'email': 'JCHEN', 'phone_number': '515.124.4269', 'hire_date': datetime.date(1997, 9, 28), 'job_id': 'FI_ACCOUNT', 'salary': 8200.0, 'commission_pct': None, 'manager_id': 108, 'department_id': 100}, {'employee_id': 111, 'first_name': 'Ismael', 'last_name': 'Sciarra', 'email': 'ISCIARRA', 'phone_number': '515.124.4369', 'hire_date': datetime.date(1997, 9, 30), 'job_id': 'FI_ACCOUNT', 'salary': 7700.0, 'commission_pct': None, 'manager_id': 108, 'department_id': 100}, {'employee_id': 112, 'first_name': 'Jose Manuel', 'last_name': 'Urman', 'email': 'JMURMAN', 'phone_number': '515.124.4469', 'hire_date': datetime.date(1998, 3, 7), 'job_id': 'FI_ACCOUNT', 'salary': 7800.0, 'commission_pct': None, 'manager_id': 108, 'department_id': 100}, {'employee_id': 113, 'first_name': 'Luis', 'last_name': 'Popp', 'email': 'LPOPP', 'phone_number': '515.124.4567', 'hire_date': datetime.date(1999, 12, 7), 'job_id': 'FI_ACCOUNT', 'salary': 6900.0, 'commission_pct': None, 'manager_id': 108, 'department_id': 100}, {'employee_id': 114, 'first_name': 'Den', 'last_name': 'Raphaely', 'email': 'DRAPHEAL', 'phone_number': '515.127.4561', 'hire_date': datetime.date(1994, 12, 7), 'job_id': 'PU_MAN', 'salary': 11000.0, 'commission_pct': None, 'manager_id': 100, 'department_id': 30}, {'employee_i ...

# %% [markdown]
# # 2. Display the first name, last name, and email of all employees.

# %%
connection = get_connection()
with connection:
    with connection.cursor() as cursor:
        sql = "SELECT first_name, last_name, email FROM employees"
        cursor.execute(sql)
        data = cursor.fetchall()
        print(data)
# Out:
# [{'first_name': 'Steven', 'last_name': 'King', 'email': 'SKING'}, {'first_name': 'Neena', 'last_name': 'Kochhar', 'email': 'NKOCHHAR'}, {'first_name': 'Lex', 'last_name': 'De Haan', 'email': 'LDEHAAN'}, {'first_name': 'Alexander', 'last_name': 'Hunold', 'email': 'AHUNOLD'}, {'first_name': 'Bruce', 'last_name': 'Ernst', 'email': 'BERNST'}, {'first_name': 'David', 'last_name': 'Austin', 'email': 'DAUSTIN'}, {'first_name': 'Valli', 'last_name': 'Pataballa', 'email': 'VPATABAL'}, {'first_name': 'Diana', 'last_name': 'Lorentz', 'email': 'DLORENTZ'}, {'first_name': 'Nancy', 'last_name': 'Greenberg', 'email': 'NGREENBE'}, {'first_name': 'Daniel', 'last_name': 'Faviet', 'email': 'DFAVIET'}, {'first_name': 'John', 'last_name': 'Chen', 'email': 'JCHEN'}, {'first_name': 'Ismael', 'last_name': 'Sciarra', 'email': 'ISCIARRA'}, {'first_name': 'Jose Manuel', 'last_name': 'Urman', 'email': 'JMURMAN'}, {'first_name': 'Luis', 'last_name': 'Popp', 'email': 'LPOPP'}, {'first_name': 'Den', 'last_name': 'Raphaely', 'email': 'DRAPHEAL'}, {'first_name': 'Alexander', 'last_name': 'Khoo', 'email': 'AKHOO'}, {'first_name': 'Shelli', 'last_name': 'Baida', 'email': 'SBAIDA'}, {'first_name': 'Sigal', 'last_name': 'Tobias', 'email': 'STOBIAS'}, {'first_name': 'Guy', 'last_name': 'Himuro', 'email': 'GHIMURO'}, {'first_name': 'Karen', 'last_name': 'Colmenares', 'email': 'KCOLMENA'}, {'first_name': 'Matthew', 'last_name': 'Weiss', 'email': 'MWEISS'}, {'first_name': 'Adam', 'last_name': 'Fripp', 'email': 'AFRIPP'}, {'first_name': 'Payam', 'last_name': 'Kaufling', 'email': 'PKAUFLIN'}, {'first_name': 'Shanta', 'last_name': 'Vollman', 'email': 'SVOLLMAN'}, {'first_name': 'Kevin', 'last_name': 'Mourgos', 'email': 'KMOURGOS'}, {'first_name': 'Julia', 'last_name': 'Nayer', 'email': 'JNAYER'}, {'first_name': 'Irene', 'last_name': 'Mikkilineni', 'email': 'IMIKKILI'}, {'first_name': 'James', 'last_name': 'Landry', 'email': 'JLANDRY'}, {'first_name': 'Steven', 'last_name': 'Markle', 'email': 'SMARKLE'}, {'first_name': 'Laura', 'last_name': 'Bissot', 'email': 'LBISSOT'}, {'first_name': 'Mozhe', 'last_name': 'Atkinson', 'email': 'MATKINSO'}, {'first_name': 'James', 'last_name': 'Marlow', 'email': 'JAMRLOW'}, {'first_name': 'TJ', 'last_name': 'Olson', 'email': 'TJOLSON'}, {'first_name': 'Jason', 'last_name': 'Mallin', 'email': 'JMALLIN'}, {'first_name': 'Michael', 'last_name': 'Rogers', 'email': 'MROGERS'}, {'first_name': 'Ki', 'last_name': 'Gee', 'email': 'KGEE'}, {'first_name': 'Hazel', 'last_name': 'Philtanker', 'email': 'HPHILTAN'}, {'first_name': 'Renske', 'last_name': 'Ladwig', 'email': 'RLADWIG'}, {'first_name': 'Stephen', 'last_name': 'Stiles', 'email': 'SSTILES'}, {'first_name': 'John', 'last_name': 'Seo', 'email': 'JSEO'}, {'first_name': 'Joshua', 'last_name': 'Patel', 'email': 'JPATEL'}, {'first_name': 'Trenna', 'last_name': 'Rajs', 'email': 'TRAJS'}, {'first_name': 'Curtis', 'last_name': 'Davies', 'email': 'CDAVIES'}, {'first_name': 'Randall', 'last_name': 'Matos', 'email': 'RMATOS'}, {'first_name': 'Peter', 'last_name': 'Vargas', 'email': 'PVARGAS'}, {'first_name': 'John', 'last_name': 'Russell', 'email': 'JRUSSEL'}, {'first_name': 'Karen', 'last_name': 'Partners', 'email': 'KPARTNER'}, {'first_name': 'Alberto', 'last_name': 'Errazuriz', 'email': 'AERRAZUR'}, {'first_name': 'Gerald', 'last_name': 'Cambrault', 'email': 'GCAMBRAU'}, {'first_name': 'Eleni', 'last_name': 'Zlotkey', 'email': 'EZLOTKEY'}, {'first_name': 'Peter', 'last_name': 'Tucker', 'email': 'PTUCKER'}, {'first_name': 'David', 'last_name': 'Bernstein', 'email': 'DBERNSTE'}, {'first_name': 'Peter', 'last_name': 'Hall', 'email': 'PHALL'}, {'first_name': 'Christopher', 'last_name': 'Olsen', 'email': 'COLSEN'}, {'first_name': 'Nanette', 'last_name': 'Cambrault', 'email': 'NCAMBRAU'}, {'first_name': 'Oliver', 'last_name': 'Tuvault', 'email': 'OTUVAULT'}, {'first_name': 'Janette', 'last_name': 'King', 'email': 'JKING'}, {'first_name': 'Patrick', 'last_name': 'Sully', 'email': 'PSULLY'}, {'first_name': ' ...

# %% [markdown]
# # 3. Retrieve the distinct job titles from the jobs table.

# %%
connection = get_connection()
with connection:
    with connection.cursor() as cursor:
        sql = "SELECT DISTINCT job_title FROM jobs"
        cursor.execute(sql)
        data = cursor.fetchall()
        print(data)
# Out:
# [{'job_title': 'Public Accountant'}, {'job_title': 'Accounting Manager'}, {'job_title': 'Administration Assistant'}, {'job_title': 'President'}, {'job_title': 'Administration Vice President'}, {'job_title': 'Accountant'}, {'job_title': 'Finance Manager'}, {'job_title': 'Human Resources Representative'}, {'job_title': 'Programmer'}, {'job_title': 'Marketing Manager'}, {'job_title': 'Marketing Representative'}, {'job_title': 'Public Relations Representative'}, {'job_title': 'Purchasing Clerk'}, {'job_title': 'Purchasing Manager'}, {'job_title': 'Sales Manager'}, {'job_title': 'Sales Representative'}, {'job_title': 'Shipping Clerk'}, {'job_title': 'Stock Clerk'}, {'job_title': 'Stock Manager'}]

# %% [markdown]
# # 4. Find the total number of employees in the company.

# %%
connection = get_connection()
with connection:
    with connection.cursor() as cursor:
        sql = "SELECT COUNT(*) AS total_employees FROM employees"
        cursor.execute(sql)
        data = cursor.fetchall()
        print(data)
# Out:
# [{'total_employees': 107}]

# %% [markdown]
# # 5. Retrieve the employees who were hired after January 1, 2015.

# %%
connection = get_connection()
with connection:
    with connection.cursor() as cursor:
        sql = "SELECT * FROM employees WHERE hire_date > '2015-01-01'"
        cursor.execute(sql)
        data = cursor.fetchall()
        print(data)
# Out:
# ()

# %% [markdown]
# # 6. List all employees who have a salary greater than 5000.

# %%
connection = get_connection()
with connection:
    with connection.cursor() as cursor:
        sql = "SELECT * FROM employees WHERE salary > 5000"
        cursor.execute(sql)
        data = cursor.fetchall()
        print(data)
# Out:
# [{'employee_id': 100, 'first_name': 'Steven', 'last_name': 'King', 'email': 'SKING', 'phone_number': '515.123.4567', 'hire_date': datetime.date(1987, 6, 17), 'job_id': 'AD_PRES', 'salary': 24000.0, 'commission_pct': None, 'manager_id': None, 'department_id': 90}, {'employee_id': 101, 'first_name': 'Neena', 'last_name': 'Kochhar', 'email': 'NKOCHHAR', 'phone_number': '515.123.4568', 'hire_date': datetime.date(1989, 9, 21), 'job_id': 'AD_VP', 'salary': 17000.0, 'commission_pct': None, 'manager_id': 100, 'department_id': 90}, {'employee_id': 102, 'first_name': 'Lex', 'last_name': 'De Haan', 'email': 'LDEHAAN', 'phone_number': '515.123.4569', 'hire_date': datetime.date(1993, 1, 13), 'job_id': 'AD_VP', 'salary': 17000.0, 'commission_pct': None, 'manager_id': 100, 'department_id': 90}, {'employee_id': 103, 'first_name': 'Alexander', 'last_name': 'Hunold', 'email': 'AHUNOLD', 'phone_number': '590.423.4567', 'hire_date': datetime.date(1990, 1, 3), 'job_id': 'IT_PROG', 'salary': 9000.0, 'commission_pct': None, 'manager_id': 102, 'department_id': 60}, {'employee_id': 104, 'first_name': 'Bruce', 'last_name': 'Ernst', 'email': 'BERNST', 'phone_number': '590.423.4568', 'hire_date': datetime.date(1991, 5, 21), 'job_id': 'IT_PROG', 'salary': 6000.0, 'commission_pct': None, 'manager_id': 103, 'department_id': 60}, {'employee_id': 108, 'first_name': 'Nancy', 'last_name': 'Greenberg', 'email': 'NGREENBE', 'phone_number': '515.124.4569', 'hire_date': datetime.date(1994, 8, 17), 'job_id': 'FI_MGR', 'salary': 12000.0, 'commission_pct': None, 'manager_id': 101, 'department_id': 100}, {'employee_id': 109, 'first_name': 'Daniel', 'last_name': 'Faviet', 'email': 'DFAVIET', 'phone_number': '515.124.4169', 'hire_date': datetime.date(1994, 8, 16), 'job_id': 'FI_ACCOUNT', 'salary': 9000.0, 'commission_pct': None, 'manager_id': 108, 'department_id': 100}, {'employee_id': 110, 'first_name': 'John', 'last_name': 'Chen', 'email': 'JCHEN', 'phone_number': '515.124.4269', 'hire_date': datetime.date(1997, 9, 28), 'job_id': 'FI_ACCOUNT', 'salary': 8200.0, 'commission_pct': None, 'manager_id': 108, 'department_id': 100}, {'employee_id': 111, 'first_name': 'Ismael', 'last_name': 'Sciarra', 'email': 'ISCIARRA', 'phone_number': '515.124.4369', 'hire_date': datetime.date(1997, 9, 30), 'job_id': 'FI_ACCOUNT', 'salary': 7700.0, 'commission_pct': None, 'manager_id': 108, 'department_id': 100}, {'employee_id': 112, 'first_name': 'Jose Manuel', 'last_name': 'Urman', 'email': 'JMURMAN', 'phone_number': '515.124.4469', 'hire_date': datetime.date(1998, 3, 7), 'job_id': 'FI_ACCOUNT', 'salary': 7800.0, 'commission_pct': None, 'manager_id': 108, 'department_id': 100}, {'employee_id': 113, 'first_name': 'Luis', 'last_name': 'Popp', 'email': 'LPOPP', 'phone_number': '515.124.4567', 'hire_date': datetime.date(1999, 12, 7), 'job_id': 'FI_ACCOUNT', 'salary': 6900.0, 'commission_pct': None, 'manager_id': 108, 'department_id': 100}, {'employee_id': 114, 'first_name': 'Den', 'last_name': 'Raphaely', 'email': 'DRAPHEAL', 'phone_number': '515.127.4561', 'hire_date': datetime.date(1994, 12, 7), 'job_id': 'PU_MAN', 'salary': 11000.0, 'commission_pct': None, 'manager_id': 100, 'department_id': 30}, {'employee_id': 120, 'first_name': 'Matthew', 'last_name': 'Weiss', 'email': 'MWEISS', 'phone_number': '650.123.1234', 'hire_date': datetime.date(1996, 7, 18), 'job_id': 'ST_MAN', 'salary': 8000.0, 'commission_pct': None, 'manager_id': 100, 'department_id': 50}, {'employee_id': 121, 'first_name': 'Adam', 'last_name': 'Fripp', 'email': 'AFRIPP', 'phone_number': '650.123.2234', 'hire_date': datetime.date(1997, 4, 10), 'job_id': 'ST_MAN', 'salary': 8200.0, 'commission_pct': None, 'manager_id': 100, 'department_id': 50}, {'employee_id': 122, 'first_name': 'Payam', 'last_name': 'Kaufling', 'email': 'PKAUFLIN', 'phone_number': '650.123.3234', 'hire_date': datetime.date(1995, 5, 1), 'job_id': 'ST_MAN', 'salary': 7900.0, 'commission_pct': None, 'manager_id': 100, 'department_id': 50}, {'employee_id': 123, ...

# %% [markdown]
# # 7. Retrieve employees with job titles containing the word ‘Manager.’

# %%
connection = get_connection()
with connection:
    with connection.cursor() as cursor:
        sql = """SELECT e.*, j.job_title 
                FROM employees e
                JOIN jobs j ON e.job_id = j.job_id
                WHERE j.job_title LIKE '%Manager%';
        """
        cursor.execute(sql)
        data = cursor.fetchall()
        print(data)
# Out:
# [{'employee_id': 205, 'first_name': 'Shelley', 'last_name': 'Higgins', 'email': 'SHIGGINS', 'phone_number': '515.123.8080', 'hire_date': datetime.date(1994, 6, 7), 'job_id': 'AC_MGR', 'salary': 12000.0, 'commission_pct': None, 'manager_id': 101, 'department_id': 110, 'job_title': 'Accounting Manager'}, {'employee_id': 108, 'first_name': 'Nancy', 'last_name': 'Greenberg', 'email': 'NGREENBE', 'phone_number': '515.124.4569', 'hire_date': datetime.date(1994, 8, 17), 'job_id': 'FI_MGR', 'salary': 12000.0, 'commission_pct': None, 'manager_id': 101, 'department_id': 100, 'job_title': 'Finance Manager'}, {'employee_id': 201, 'first_name': 'Michael', 'last_name': 'Hartstein', 'email': 'MHARTSTE', 'phone_number': '515.123.5555', 'hire_date': datetime.date(1996, 2, 17), 'job_id': 'MK_MAN', 'salary': 13000.0, 'commission_pct': None, 'manager_id': 100, 'department_id': 20, 'job_title': 'Marketing Manager'}, {'employee_id': 114, 'first_name': 'Den', 'last_name': 'Raphaely', 'email': 'DRAPHEAL', 'phone_number': '515.127.4561', 'hire_date': datetime.date(1994, 12, 7), 'job_id': 'PU_MAN', 'salary': 11000.0, 'commission_pct': None, 'manager_id': 100, 'department_id': 30, 'job_title': 'Purchasing Manager'}, {'employee_id': 145, 'first_name': 'John', 'last_name': 'Russell', 'email': 'JRUSSEL', 'phone_number': '011.44.1344.429268', 'hire_date': datetime.date(1996, 10, 1), 'job_id': 'SA_MAN', 'salary': 14000.0, 'commission_pct': 0.4, 'manager_id': 100, 'department_id': 80, 'job_title': 'Sales Manager'}, {'employee_id': 146, 'first_name': 'Karen', 'last_name': 'Partners', 'email': 'KPARTNER', 'phone_number': '011.44.1344.467268', 'hire_date': datetime.date(1997, 1, 5), 'job_id': 'SA_MAN', 'salary': 13500.0, 'commission_pct': 0.3, 'manager_id': 100, 'department_id': 80, 'job_title': 'Sales Manager'}, {'employee_id': 147, 'first_name': 'Alberto', 'last_name': 'Errazuriz', 'email': 'AERRAZUR', 'phone_number': '011.44.1344.429278', 'hire_date': datetime.date(1997, 3, 10), 'job_id': 'SA_MAN', 'salary': 12000.0, 'commission_pct': 0.3, 'manager_id': 100, 'department_id': 80, 'job_title': 'Sales Manager'}, {'employee_id': 148, 'first_name': 'Gerald', 'last_name': 'Cambrault', 'email': 'GCAMBRAU', 'phone_number': '011.44.1344.619268', 'hire_date': datetime.date(1999, 10, 15), 'job_id': 'SA_MAN', 'salary': 11000.0, 'commission_pct': 0.3, 'manager_id': 100, 'department_id': 80, 'job_title': 'Sales Manager'}, {'employee_id': 149, 'first_name': 'Eleni', 'last_name': 'Zlotkey', 'email': 'EZLOTKEY', 'phone_number': '011.44.1344.429018', 'hire_date': datetime.date(2000, 1, 29), 'job_id': 'SA_MAN', 'salary': 10500.0, 'commission_pct': 0.2, 'manager_id': 100, 'department_id': 80, 'job_title': 'Sales Manager'}, {'employee_id': 120, 'first_name': 'Matthew', 'last_name': 'Weiss', 'email': 'MWEISS', 'phone_number': '650.123.1234', 'hire_date': datetime.date(1996, 7, 18), 'job_id': 'ST_MAN', 'salary': 8000.0, 'commission_pct': None, 'manager_id': 100, 'department_id': 50, 'job_title': 'Stock Manager'}, {'employee_id': 121, 'first_name': 'Adam', 'last_name': 'Fripp', 'email': 'AFRIPP', 'phone_number': '650.123.2234', 'hire_date': datetime.date(1997, 4, 10), 'job_id': 'ST_MAN', 'salary': 8200.0, 'commission_pct': None, 'manager_id': 100, 'department_id': 50, 'job_title': 'Stock Manager'}, {'employee_id': 122, 'first_name': 'Payam', 'last_name': 'Kaufling', 'email': 'PKAUFLIN', 'phone_number': '650.123.3234', 'hire_date': datetime.date(1995, 5, 1), 'job_id': 'ST_MAN', 'salary': 7900.0, 'commission_pct': None, 'manager_id': 100, 'department_id': 50, 'job_title': 'Stock Manager'}, {'employee_id': 123, 'first_name': 'Shanta', 'last_name': 'Vollman', 'email': 'SVOLLMAN', 'phone_number': '650.123.4234', 'hire_date': datetime.date(1997, 10, 10), 'job_id': 'ST_MAN', 'salary': 6500.0, 'commission_pct': None, 'manager_id': 100, 'department_id': 50, 'job_title': 'Stock Manager'}, {'employee_id': 124, 'first_name': 'Kevin', 'last_name': 'Mourgos', 'email': 'KMOURGOS', 'phone_number':  ...

# %% [markdown]
# # 8. Retrieve all employees whose first name starts with ‘A’ and ends with ‘n.’

# %%
connection = get_connection()
with connection:
    with connection.cursor() as cursor:
        sql = "SELECT * FROM employees WHERE first_name LIKE 'A%n'"
        cursor.execute(sql)
        data = cursor.fetchall()
        print(data)
# Out:
# [{'employee_id': 158, 'first_name': 'Allan', 'last_name': 'McEwen', 'email': 'AMCEWEN', 'phone_number': '011.44.1345.829268', 'hire_date': datetime.date(1996, 8, 1), 'job_id': 'SA_REP', 'salary': 9000.0, 'commission_pct': 0.35, 'manager_id': 146, 'department_id': 80}]

# %% [markdown]
# # 9. Display the employees who do not have a commission.

# %%
connection = get_connection()
with connection:
    with connection.cursor() as cursor:
        # Create a new record
        sql = "SELECT * FROM employees WHERE commission_pct IS NULL OR commission_pct = 0"
        cursor.execute(sql)
        data = cursor.fetchall()
        print(data)
# Out:
# [{'employee_id': 100, 'first_name': 'Steven', 'last_name': 'King', 'email': 'SKING', 'phone_number': '515.123.4567', 'hire_date': datetime.date(1987, 6, 17), 'job_id': 'AD_PRES', 'salary': 24000.0, 'commission_pct': None, 'manager_id': None, 'department_id': 90}, {'employee_id': 101, 'first_name': 'Neena', 'last_name': 'Kochhar', 'email': 'NKOCHHAR', 'phone_number': '515.123.4568', 'hire_date': datetime.date(1989, 9, 21), 'job_id': 'AD_VP', 'salary': 17000.0, 'commission_pct': None, 'manager_id': 100, 'department_id': 90}, {'employee_id': 102, 'first_name': 'Lex', 'last_name': 'De Haan', 'email': 'LDEHAAN', 'phone_number': '515.123.4569', 'hire_date': datetime.date(1993, 1, 13), 'job_id': 'AD_VP', 'salary': 17000.0, 'commission_pct': None, 'manager_id': 100, 'department_id': 90}, {'employee_id': 103, 'first_name': 'Alexander', 'last_name': 'Hunold', 'email': 'AHUNOLD', 'phone_number': '590.423.4567', 'hire_date': datetime.date(1990, 1, 3), 'job_id': 'IT_PROG', 'salary': 9000.0, 'commission_pct': None, 'manager_id': 102, 'department_id': 60}, {'employee_id': 104, 'first_name': 'Bruce', 'last_name': 'Ernst', 'email': 'BERNST', 'phone_number': '590.423.4568', 'hire_date': datetime.date(1991, 5, 21), 'job_id': 'IT_PROG', 'salary': 6000.0, 'commission_pct': None, 'manager_id': 103, 'department_id': 60}, {'employee_id': 105, 'first_name': 'David', 'last_name': 'Austin', 'email': 'DAUSTIN', 'phone_number': '590.423.4569', 'hire_date': datetime.date(1997, 6, 25), 'job_id': 'IT_PROG', 'salary': 4800.0, 'commission_pct': None, 'manager_id': 103, 'department_id': 60}, {'employee_id': 106, 'first_name': 'Valli', 'last_name': 'Pataballa', 'email': 'VPATABAL', 'phone_number': '590.423.4560', 'hire_date': datetime.date(1998, 2, 5), 'job_id': 'IT_PROG', 'salary': 4800.0, 'commission_pct': None, 'manager_id': 103, 'department_id': 60}, {'employee_id': 107, 'first_name': 'Diana', 'last_name': 'Lorentz', 'email': 'DLORENTZ', 'phone_number': '590.423.5567', 'hire_date': datetime.date(1999, 2, 7), 'job_id': 'IT_PROG', 'salary': 4200.0, 'commission_pct': None, 'manager_id': 103, 'department_id': 60}, {'employee_id': 108, 'first_name': 'Nancy', 'last_name': 'Greenberg', 'email': 'NGREENBE', 'phone_number': '515.124.4569', 'hire_date': datetime.date(1994, 8, 17), 'job_id': 'FI_MGR', 'salary': 12000.0, 'commission_pct': None, 'manager_id': 101, 'department_id': 100}, {'employee_id': 109, 'first_name': 'Daniel', 'last_name': 'Faviet', 'email': 'DFAVIET', 'phone_number': '515.124.4169', 'hire_date': datetime.date(1994, 8, 16), 'job_id': 'FI_ACCOUNT', 'salary': 9000.0, 'commission_pct': None, 'manager_id': 108, 'department_id': 100}, {'employee_id': 110, 'first_name': 'John', 'last_name': 'Chen', 'email': 'JCHEN', 'phone_number': '515.124.4269', 'hire_date': datetime.date(1997, 9, 28), 'job_id': 'FI_ACCOUNT', 'salary': 8200.0, 'commission_pct': None, 'manager_id': 108, 'department_id': 100}, {'employee_id': 111, 'first_name': 'Ismael', 'last_name': 'Sciarra', 'email': 'ISCIARRA', 'phone_number': '515.124.4369', 'hire_date': datetime.date(1997, 9, 30), 'job_id': 'FI_ACCOUNT', 'salary': 7700.0, 'commission_pct': None, 'manager_id': 108, 'department_id': 100}, {'employee_id': 112, 'first_name': 'Jose Manuel', 'last_name': 'Urman', 'email': 'JMURMAN', 'phone_number': '515.124.4469', 'hire_date': datetime.date(1998, 3, 7), 'job_id': 'FI_ACCOUNT', 'salary': 7800.0, 'commission_pct': None, 'manager_id': 108, 'department_id': 100}, {'employee_id': 113, 'first_name': 'Luis', 'last_name': 'Popp', 'email': 'LPOPP', 'phone_number': '515.124.4567', 'hire_date': datetime.date(1999, 12, 7), 'job_id': 'FI_ACCOUNT', 'salary': 6900.0, 'commission_pct': None, 'manager_id': 108, 'department_id': 100}, {'employee_id': 114, 'first_name': 'Den', 'last_name': 'Raphaely', 'email': 'DRAPHEAL', 'phone_number': '515.127.4561', 'hire_date': datetime.date(1994, 12, 7), 'job_id': 'PU_MAN', 'salary': 11000.0, 'commission_pct': None, 'manager_id': 100, 'department_id': 30}, {'employee_i ...

# %% [markdown]
# # 10. Retrieve the top 5 highest-paid employees.

# %%
connection = get_connection()
with connection:
    with connection.cursor() as cursor:
        sql = "SELECT * FROM employees ORDER BY salary DESC LIMIT 5"
        cursor.execute(sql)
        data = cursor.fetchall()
        print(data)
# Out:
# [{'employee_id': 100, 'first_name': 'Steven', 'last_name': 'King', 'email': 'SKING', 'phone_number': '515.123.4567', 'hire_date': datetime.date(1987, 6, 17), 'job_id': 'AD_PRES', 'salary': 24000.0, 'commission_pct': None, 'manager_id': None, 'department_id': 90}, {'employee_id': 101, 'first_name': 'Neena', 'last_name': 'Kochhar', 'email': 'NKOCHHAR', 'phone_number': '515.123.4568', 'hire_date': datetime.date(1989, 9, 21), 'job_id': 'AD_VP', 'salary': 17000.0, 'commission_pct': None, 'manager_id': 100, 'department_id': 90}, {'employee_id': 102, 'first_name': 'Lex', 'last_name': 'De Haan', 'email': 'LDEHAAN', 'phone_number': '515.123.4569', 'hire_date': datetime.date(1993, 1, 13), 'job_id': 'AD_VP', 'salary': 17000.0, 'commission_pct': None, 'manager_id': 100, 'department_id': 90}, {'employee_id': 145, 'first_name': 'John', 'last_name': 'Russell', 'email': 'JRUSSEL', 'phone_number': '011.44.1344.429268', 'hire_date': datetime.date(1996, 10, 1), 'job_id': 'SA_MAN', 'salary': 14000.0, 'commission_pct': 0.4, 'manager_id': 100, 'department_id': 80}, {'employee_id': 146, 'first_name': 'Karen', 'last_name': 'Partners', 'email': 'KPARTNER', 'phone_number': '011.44.1344.467268', 'hire_date': datetime.date(1997, 1, 5), 'job_id': 'SA_MAN', 'salary': 13500.0, 'commission_pct': 0.3, 'manager_id': 100, 'department_id': 80}]

# %% [markdown]
# # 11. Find the average salary of all employees.

# %%
connection = get_connection()
with connection:
    with connection.cursor() as cursor:
        sql = "SELECT AVG(salary) AS average_salary FROM employees"
        cursor.execute(sql)
        data = cursor.fetchall()
        print(data)
# Out:
# [{'average_salary': 6461.682242990654}]

# %% [markdown]
# # 12. Retrieve the total number of employees working in each department.

# %%
connection = get_connection()
with connection:
    with connection.cursor() as cursor:
        sql = """SELECT department_id, COUNT(*) AS employee_count 
                 FROM employees 
                 GROUP BY department_id;
             """
        cursor.execute(sql)
        data = cursor.fetchall()
        print(data)
# Out:
# [{'department_id': None, 'employee_count': 1}, {'department_id': 10, 'employee_count': 1}, {'department_id': 20, 'employee_count': 2}, {'department_id': 30, 'employee_count': 6}, {'department_id': 40, 'employee_count': 1}, {'department_id': 50, 'employee_count': 45}, {'department_id': 60, 'employee_count': 5}, {'department_id': 70, 'employee_count': 1}, {'department_id': 80, 'employee_count': 34}, {'department_id': 90, 'employee_count': 3}, {'department_id': 100, 'employee_count': 6}, {'department_id': 110, 'employee_count': 2}]

# %% [markdown]
# # 13. Display the employee's first name and the length of their first name.

# %%
connection = get_connection()
with connection:
    with connection.cursor() as cursor:
        sql = "SELECT first_name, LENGTH(first_name) AS name_length FROM employees"
        cursor.execute(sql)
        data = cursor.fetchall()
        print(data)
# Out:
# [{'first_name': 'Steven', 'name_length': 6}, {'first_name': 'Neena', 'name_length': 5}, {'first_name': 'Lex', 'name_length': 3}, {'first_name': 'Alexander', 'name_length': 9}, {'first_name': 'Bruce', 'name_length': 5}, {'first_name': 'David', 'name_length': 5}, {'first_name': 'Valli', 'name_length': 5}, {'first_name': 'Diana', 'name_length': 5}, {'first_name': 'Nancy', 'name_length': 5}, {'first_name': 'Daniel', 'name_length': 6}, {'first_name': 'John', 'name_length': 4}, {'first_name': 'Ismael', 'name_length': 6}, {'first_name': 'Jose Manuel', 'name_length': 11}, {'first_name': 'Luis', 'name_length': 4}, {'first_name': 'Den', 'name_length': 3}, {'first_name': 'Alexander', 'name_length': 9}, {'first_name': 'Shelli', 'name_length': 6}, {'first_name': 'Sigal', 'name_length': 5}, {'first_name': 'Guy', 'name_length': 3}, {'first_name': 'Karen', 'name_length': 5}, {'first_name': 'Matthew', 'name_length': 7}, {'first_name': 'Adam', 'name_length': 4}, {'first_name': 'Payam', 'name_length': 5}, {'first_name': 'Shanta', 'name_length': 6}, {'first_name': 'Kevin', 'name_length': 5}, {'first_name': 'Julia', 'name_length': 5}, {'first_name': 'Irene', 'name_length': 5}, {'first_name': 'James', 'name_length': 5}, {'first_name': 'Steven', 'name_length': 6}, {'first_name': 'Laura', 'name_length': 5}, {'first_name': 'Mozhe', 'name_length': 5}, {'first_name': 'James', 'name_length': 5}, {'first_name': 'TJ', 'name_length': 2}, {'first_name': 'Jason', 'name_length': 5}, {'first_name': 'Michael', 'name_length': 7}, {'first_name': 'Ki', 'name_length': 2}, {'first_name': 'Hazel', 'name_length': 5}, {'first_name': 'Renske', 'name_length': 6}, {'first_name': 'Stephen', 'name_length': 7}, {'first_name': 'John', 'name_length': 4}, {'first_name': 'Joshua', 'name_length': 6}, {'first_name': 'Trenna', 'name_length': 6}, {'first_name': 'Curtis', 'name_length': 6}, {'first_name': 'Randall', 'name_length': 7}, {'first_name': 'Peter', 'name_length': 5}, {'first_name': 'John', 'name_length': 4}, {'first_name': 'Karen', 'name_length': 5}, {'first_name': 'Alberto', 'name_length': 7}, {'first_name': 'Gerald', 'name_length': 6}, {'first_name': 'Eleni', 'name_length': 5}, {'first_name': 'Peter', 'name_length': 5}, {'first_name': 'David', 'name_length': 5}, {'first_name': 'Peter', 'name_length': 5}, {'first_name': 'Christopher', 'name_length': 11}, {'first_name': 'Nanette', 'name_length': 7}, {'first_name': 'Oliver', 'name_length': 6}, {'first_name': 'Janette', 'name_length': 7}, {'first_name': 'Patrick', 'name_length': 7}, {'first_name': 'Allan', 'name_length': 5}, {'first_name': 'Lindsey', 'name_length': 7}, {'first_name': 'Louise', 'name_length': 6}, {'first_name': 'Sarath', 'name_length': 6}, {'first_name': 'Clara', 'name_length': 5}, {'first_name': 'Danielle', 'name_length': 8}, {'first_name': 'Mattea', 'name_length': 6}, {'first_name': 'David', 'name_length': 5}, {'first_name': 'Sundar', 'name_length': 6}, {'first_name': 'Amit', 'name_length': 4}, {'first_name': 'Lisa', 'name_length': 4}, {'first_name': 'Harrison', 'name_length': 8}, {'first_name': 'Tayler', 'name_length': 6}, {'first_name': 'William', 'name_length': 7}, {'first_name': 'Elizabeth', 'name_length': 9}, {'first_name': 'Sundita', 'name_length': 7}, {'first_name': 'Ellen', 'name_length': 5}, {'first_name': 'Alyssa', 'name_length': 6}, {'first_name': 'Jonathon', 'name_length': 8}, {'first_name': 'Jack', 'name_length': 4}, {'first_name': 'Kimberely', 'name_length': 9}, {'first_name': 'Charles', 'name_length': 7}, {'first_name': 'Winston', 'name_length': 7}, {'first_name': 'Jean', 'name_length': 4}, {'first_name': 'Martha', 'name_length': 6}, {'first_name': 'Girard', 'name_length': 6}, {'first_name': 'Nandita', 'name_length': 7}, {'first_name': 'Alexis', 'name_length': 6}, {'first_name': 'Julia', 'name_length': 5}, {'first_name': 'Anthony', 'name_length': 7}, {'first_name': 'Kelly', 'name_length': 5}, {'first_name': 'Jennifer', 'name_length': 8}, {'first_name': 'Timothy', 'name_length': 7}, {'first_name ...

# %% [markdown]
# # 14. Convert the hire_date of employees to display only the year.

# %%
connection = get_connection()
with connection:
    with connection.cursor() as cursor:
        sql = "SELECT first_name, last_name, EXTRACT(YEAR FROM hire_date) AS hire_year FROM employees"
        cursor.execute(sql)
        data = cursor.fetchall()
        print(data)
# Out:
# [{'first_name': 'Steven', 'last_name': 'King', 'hire_year': 1987}, {'first_name': 'Neena', 'last_name': 'Kochhar', 'hire_year': 1989}, {'first_name': 'Lex', 'last_name': 'De Haan', 'hire_year': 1993}, {'first_name': 'Alexander', 'last_name': 'Hunold', 'hire_year': 1990}, {'first_name': 'Bruce', 'last_name': 'Ernst', 'hire_year': 1991}, {'first_name': 'David', 'last_name': 'Austin', 'hire_year': 1997}, {'first_name': 'Valli', 'last_name': 'Pataballa', 'hire_year': 1998}, {'first_name': 'Diana', 'last_name': 'Lorentz', 'hire_year': 1999}, {'first_name': 'Nancy', 'last_name': 'Greenberg', 'hire_year': 1994}, {'first_name': 'Daniel', 'last_name': 'Faviet', 'hire_year': 1994}, {'first_name': 'John', 'last_name': 'Chen', 'hire_year': 1997}, {'first_name': 'Ismael', 'last_name': 'Sciarra', 'hire_year': 1997}, {'first_name': 'Jose Manuel', 'last_name': 'Urman', 'hire_year': 1998}, {'first_name': 'Luis', 'last_name': 'Popp', 'hire_year': 1999}, {'first_name': 'Den', 'last_name': 'Raphaely', 'hire_year': 1994}, {'first_name': 'Alexander', 'last_name': 'Khoo', 'hire_year': 1995}, {'first_name': 'Shelli', 'last_name': 'Baida', 'hire_year': 1997}, {'first_name': 'Sigal', 'last_name': 'Tobias', 'hire_year': 1997}, {'first_name': 'Guy', 'last_name': 'Himuro', 'hire_year': 1998}, {'first_name': 'Karen', 'last_name': 'Colmenares', 'hire_year': 1999}, {'first_name': 'Matthew', 'last_name': 'Weiss', 'hire_year': 1996}, {'first_name': 'Adam', 'last_name': 'Fripp', 'hire_year': 1997}, {'first_name': 'Payam', 'last_name': 'Kaufling', 'hire_year': 1995}, {'first_name': 'Shanta', 'last_name': 'Vollman', 'hire_year': 1997}, {'first_name': 'Kevin', 'last_name': 'Mourgos', 'hire_year': 1999}, {'first_name': 'Julia', 'last_name': 'Nayer', 'hire_year': 1997}, {'first_name': 'Irene', 'last_name': 'Mikkilineni', 'hire_year': 1998}, {'first_name': 'James', 'last_name': 'Landry', 'hire_year': 1999}, {'first_name': 'Steven', 'last_name': 'Markle', 'hire_year': 2000}, {'first_name': 'Laura', 'last_name': 'Bissot', 'hire_year': 1997}, {'first_name': 'Mozhe', 'last_name': 'Atkinson', 'hire_year': 1997}, {'first_name': 'James', 'last_name': 'Marlow', 'hire_year': 1997}, {'first_name': 'TJ', 'last_name': 'Olson', 'hire_year': 1999}, {'first_name': 'Jason', 'last_name': 'Mallin', 'hire_year': 1996}, {'first_name': 'Michael', 'last_name': 'Rogers', 'hire_year': 1998}, {'first_name': 'Ki', 'last_name': 'Gee', 'hire_year': 1999}, {'first_name': 'Hazel', 'last_name': 'Philtanker', 'hire_year': 2000}, {'first_name': 'Renske', 'last_name': 'Ladwig', 'hire_year': 1995}, {'first_name': 'Stephen', 'last_name': 'Stiles', 'hire_year': 1997}, {'first_name': 'John', 'last_name': 'Seo', 'hire_year': 1998}, {'first_name': 'Joshua', 'last_name': 'Patel', 'hire_year': 1998}, {'first_name': 'Trenna', 'last_name': 'Rajs', 'hire_year': 1995}, {'first_name': 'Curtis', 'last_name': 'Davies', 'hire_year': 1997}, {'first_name': 'Randall', 'last_name': 'Matos', 'hire_year': 1998}, {'first_name': 'Peter', 'last_name': 'Vargas', 'hire_year': 1998}, {'first_name': 'John', 'last_name': 'Russell', 'hire_year': 1996}, {'first_name': 'Karen', 'last_name': 'Partners', 'hire_year': 1997}, {'first_name': 'Alberto', 'last_name': 'Errazuriz', 'hire_year': 1997}, {'first_name': 'Gerald', 'last_name': 'Cambrault', 'hire_year': 1999}, {'first_name': 'Eleni', 'last_name': 'Zlotkey', 'hire_year': 2000}, {'first_name': 'Peter', 'last_name': 'Tucker', 'hire_year': 1997}, {'first_name': 'David', 'last_name': 'Bernstein', 'hire_year': 1997}, {'first_name': 'Peter', 'last_name': 'Hall', 'hire_year': 1997}, {'first_name': 'Christopher', 'last_name': 'Olsen', 'hire_year': 1998}, {'first_name': 'Nanette', 'last_name': 'Cambrault', 'hire_year': 1998}, {'first_name': 'Oliver', 'last_name': 'Tuvault', 'hire_year': 1999}, {'first_name': 'Janette', 'last_name': 'King', 'hire_year': 1996}, {'first_name': 'Patrick', 'last_name': 'Sully', 'hire_year': 1996}, {'first_name': 'Allan', 'last_name': 'McEwen', 'hire_year': 1996} ...

# %% [markdown]
# # 15. Retrieve the minimum and maximum salary for each job title.

# %%
connection = get_connection()
with connection:
    with connection.cursor() as cursor:
        sql = """SELECT j.job_title, MIN(e.salary) AS min_salary, MAX(e.salary) AS max_salary
                FROM employees e
                JOIN jobs j ON e.job_id = j.job_id
                GROUP BY j.job_title
              """
        cursor.execute(sql)
        data = cursor.fetchall()
        print(data)
# Out:
# [{'job_title': 'Public Accountant', 'min_salary': 8300.0, 'max_salary': 8300.0}, {'job_title': 'Accounting Manager', 'min_salary': 12000.0, 'max_salary': 12000.0}, {'job_title': 'Administration Assistant', 'min_salary': 4400.0, 'max_salary': 4400.0}, {'job_title': 'President', 'min_salary': 24000.0, 'max_salary': 24000.0}, {'job_title': 'Administration Vice President', 'min_salary': 17000.0, 'max_salary': 17000.0}, {'job_title': 'Accountant', 'min_salary': 6900.0, 'max_salary': 9000.0}, {'job_title': 'Finance Manager', 'min_salary': 12000.0, 'max_salary': 12000.0}, {'job_title': 'Human Resources Representative', 'min_salary': 6500.0, 'max_salary': 6500.0}, {'job_title': 'Programmer', 'min_salary': 4200.0, 'max_salary': 9000.0}, {'job_title': 'Marketing Manager', 'min_salary': 13000.0, 'max_salary': 13000.0}, {'job_title': 'Marketing Representative', 'min_salary': 6000.0, 'max_salary': 6000.0}, {'job_title': 'Public Relations Representative', 'min_salary': 10000.0, 'max_salary': 10000.0}, {'job_title': 'Purchasing Clerk', 'min_salary': 2500.0, 'max_salary': 3100.0}, {'job_title': 'Purchasing Manager', 'min_salary': 11000.0, 'max_salary': 11000.0}, {'job_title': 'Sales Manager', 'min_salary': 10500.0, 'max_salary': 14000.0}, {'job_title': 'Sales Representative', 'min_salary': 6100.0, 'max_salary': 11500.0}, {'job_title': 'Shipping Clerk', 'min_salary': 2500.0, 'max_salary': 4200.0}, {'job_title': 'Stock Clerk', 'min_salary': 2100.0, 'max_salary': 3600.0}, {'job_title': 'Stock Manager', 'min_salary': 5800.0, 'max_salary': 8200.0}]

# %% [markdown]
# # 16. Retrieve the employee names along with their department names.

# %%
connection = get_connection()
with connection:
    with connection.cursor() as cursor:
        sql = """SELECT e.first_name, e.last_name, d.department_name
                 FROM employees e
                 JOIN departments d ON e.department_id = d.department_id;
              """
        cursor.execute(sql)
        data = cursor.fetchall()
        print(data)
# Out:
# [{'first_name': 'Jennifer', 'last_name': 'Whalen', 'department_name': 'Administration'}, {'first_name': 'Michael', 'last_name': 'Hartstein', 'department_name': 'Marketing'}, {'first_name': 'Pat', 'last_name': 'Fay', 'department_name': 'Marketing'}, {'first_name': 'Den', 'last_name': 'Raphaely', 'department_name': 'Purchasing'}, {'first_name': 'Alexander', 'last_name': 'Khoo', 'department_name': 'Purchasing'}, {'first_name': 'Shelli', 'last_name': 'Baida', 'department_name': 'Purchasing'}, {'first_name': 'Sigal', 'last_name': 'Tobias', 'department_name': 'Purchasing'}, {'first_name': 'Guy', 'last_name': 'Himuro', 'department_name': 'Purchasing'}, {'first_name': 'Karen', 'last_name': 'Colmenares', 'department_name': 'Purchasing'}, {'first_name': 'Susan', 'last_name': 'Mavris', 'department_name': 'Human Resources'}, {'first_name': 'Matthew', 'last_name': 'Weiss', 'department_name': 'Shipping'}, {'first_name': 'Adam', 'last_name': 'Fripp', 'department_name': 'Shipping'}, {'first_name': 'Payam', 'last_name': 'Kaufling', 'department_name': 'Shipping'}, {'first_name': 'Shanta', 'last_name': 'Vollman', 'department_name': 'Shipping'}, {'first_name': 'Kevin', 'last_name': 'Mourgos', 'department_name': 'Shipping'}, {'first_name': 'Julia', 'last_name': 'Nayer', 'department_name': 'Shipping'}, {'first_name': 'Irene', 'last_name': 'Mikkilineni', 'department_name': 'Shipping'}, {'first_name': 'James', 'last_name': 'Landry', 'department_name': 'Shipping'}, {'first_name': 'Steven', 'last_name': 'Markle', 'department_name': 'Shipping'}, {'first_name': 'Laura', 'last_name': 'Bissot', 'department_name': 'Shipping'}, {'first_name': 'Mozhe', 'last_name': 'Atkinson', 'department_name': 'Shipping'}, {'first_name': 'James', 'last_name': 'Marlow', 'department_name': 'Shipping'}, {'first_name': 'TJ', 'last_name': 'Olson', 'department_name': 'Shipping'}, {'first_name': 'Jason', 'last_name': 'Mallin', 'department_name': 'Shipping'}, {'first_name': 'Michael', 'last_name': 'Rogers', 'department_name': 'Shipping'}, {'first_name': 'Ki', 'last_name': 'Gee', 'department_name': 'Shipping'}, {'first_name': 'Hazel', 'last_name': 'Philtanker', 'department_name': 'Shipping'}, {'first_name': 'Renske', 'last_name': 'Ladwig', 'department_name': 'Shipping'}, {'first_name': 'Stephen', 'last_name': 'Stiles', 'department_name': 'Shipping'}, {'first_name': 'John', 'last_name': 'Seo', 'department_name': 'Shipping'}, {'first_name': 'Joshua', 'last_name': 'Patel', 'department_name': 'Shipping'}, {'first_name': 'Trenna', 'last_name': 'Rajs', 'department_name': 'Shipping'}, {'first_name': 'Curtis', 'last_name': 'Davies', 'department_name': 'Shipping'}, {'first_name': 'Randall', 'last_name': 'Matos', 'department_name': 'Shipping'}, {'first_name': 'Peter', 'last_name': 'Vargas', 'department_name': 'Shipping'}, {'first_name': 'Winston', 'last_name': 'Taylor', 'department_name': 'Shipping'}, {'first_name': 'Jean', 'last_name': 'Fleaur', 'department_name': 'Shipping'}, {'first_name': 'Martha', 'last_name': 'Sullivan', 'department_name': 'Shipping'}, {'first_name': 'Girard', 'last_name': 'Geoni', 'department_name': 'Shipping'}, {'first_name': 'Nandita', 'last_name': 'Sarchand', 'department_name': 'Shipping'}, {'first_name': 'Alexis', 'last_name': 'Bull', 'department_name': 'Shipping'}, {'first_name': 'Julia', 'last_name': 'Dellinger', 'department_name': 'Shipping'}, {'first_name': 'Anthony', 'last_name': 'Cabrio', 'department_name': 'Shipping'}, {'first_name': 'Kelly', 'last_name': 'Chung', 'department_name': 'Shipping'}, {'first_name': 'Jennifer', 'last_name': 'Dilly', 'department_name': 'Shipping'}, {'first_name': 'Timothy', 'last_name': 'Gates', 'department_name': 'Shipping'}, {'first_name': 'Randall', 'last_name': 'Perkins', 'department_name': 'Shipping'}, {'first_name': 'Sarah', 'last_name': 'Bell', 'department_name': 'Shipping'}, {'first_name': 'Britney', 'last_name': 'Everett', 'department_name': 'Shipping'}, {'first_name': 'Samuel', 'last_name': 'McCain', 'department_name': 'S ...

# %% [markdown]
# # 17. List the employees along with their job titles and the location of their department.

# %%
connection = get_connection()
with connection:
    with connection.cursor() as cursor:
        sql = """SELECT e.first_name, e.last_name, j.job_title, l.city, l.country_id
                FROM employees e
                JOIN jobs j ON e.job_id = j.job_id
                JOIN departments d ON e.department_id = d.department_id
                JOIN locations l ON d.location_id = l.location_id;
              """
        cursor.execute(sql)
        data = cursor.fetchall()
        print(data)
# Out:
# [{'first_name': 'William', 'last_name': 'Gietz', 'job_title': 'Public Accountant', 'city': 'Seattle', 'country_id': 'US'}, {'first_name': 'Shelley', 'last_name': 'Higgins', 'job_title': 'Accounting Manager', 'city': 'Seattle', 'country_id': 'US'}, {'first_name': 'Jennifer', 'last_name': 'Whalen', 'job_title': 'Administration Assistant', 'city': 'Seattle', 'country_id': 'US'}, {'first_name': 'Steven', 'last_name': 'King', 'job_title': 'President', 'city': 'Seattle', 'country_id': 'US'}, {'first_name': 'Neena', 'last_name': 'Kochhar', 'job_title': 'Administration Vice President', 'city': 'Seattle', 'country_id': 'US'}, {'first_name': 'Lex', 'last_name': 'De Haan', 'job_title': 'Administration Vice President', 'city': 'Seattle', 'country_id': 'US'}, {'first_name': 'Daniel', 'last_name': 'Faviet', 'job_title': 'Accountant', 'city': 'Seattle', 'country_id': 'US'}, {'first_name': 'John', 'last_name': 'Chen', 'job_title': 'Accountant', 'city': 'Seattle', 'country_id': 'US'}, {'first_name': 'Ismael', 'last_name': 'Sciarra', 'job_title': 'Accountant', 'city': 'Seattle', 'country_id': 'US'}, {'first_name': 'Jose Manuel', 'last_name': 'Urman', 'job_title': 'Accountant', 'city': 'Seattle', 'country_id': 'US'}, {'first_name': 'Luis', 'last_name': 'Popp', 'job_title': 'Accountant', 'city': 'Seattle', 'country_id': 'US'}, {'first_name': 'Nancy', 'last_name': 'Greenberg', 'job_title': 'Finance Manager', 'city': 'Seattle', 'country_id': 'US'}, {'first_name': 'Susan', 'last_name': 'Mavris', 'job_title': 'Human Resources Representative', 'city': 'London', 'country_id': 'UK'}, {'first_name': 'Alexander', 'last_name': 'Hunold', 'job_title': 'Programmer', 'city': 'Southlake', 'country_id': 'US'}, {'first_name': 'Bruce', 'last_name': 'Ernst', 'job_title': 'Programmer', 'city': 'Southlake', 'country_id': 'US'}, {'first_name': 'David', 'last_name': 'Austin', 'job_title': 'Programmer', 'city': 'Southlake', 'country_id': 'US'}, {'first_name': 'Valli', 'last_name': 'Pataballa', 'job_title': 'Programmer', 'city': 'Southlake', 'country_id': 'US'}, {'first_name': 'Diana', 'last_name': 'Lorentz', 'job_title': 'Programmer', 'city': 'Southlake', 'country_id': 'US'}, {'first_name': 'Michael', 'last_name': 'Hartstein', 'job_title': 'Marketing Manager', 'city': 'Toronto', 'country_id': 'CA'}, {'first_name': 'Pat', 'last_name': 'Fay', 'job_title': 'Marketing Representative', 'city': 'Toronto', 'country_id': 'CA'}, {'first_name': 'Hermann', 'last_name': 'Baer', 'job_title': 'Public Relations Representative', 'city': 'Munich', 'country_id': 'DE'}, {'first_name': 'Alexander', 'last_name': 'Khoo', 'job_title': 'Purchasing Clerk', 'city': 'Seattle', 'country_id': 'US'}, {'first_name': 'Shelli', 'last_name': 'Baida', 'job_title': 'Purchasing Clerk', 'city': 'Seattle', 'country_id': 'US'}, {'first_name': 'Sigal', 'last_name': 'Tobias', 'job_title': 'Purchasing Clerk', 'city': 'Seattle', 'country_id': 'US'}, {'first_name': 'Guy', 'last_name': 'Himuro', 'job_title': 'Purchasing Clerk', 'city': 'Seattle', 'country_id': 'US'}, {'first_name': 'Karen', 'last_name': 'Colmenares', 'job_title': 'Purchasing Clerk', 'city': 'Seattle', 'country_id': 'US'}, {'first_name': 'Den', 'last_name': 'Raphaely', 'job_title': 'Purchasing Manager', 'city': 'Seattle', 'country_id': 'US'}, {'first_name': 'John', 'last_name': 'Russell', 'job_title': 'Sales Manager', 'city': 'Oxford', 'country_id': 'UK'}, {'first_name': 'Karen', 'last_name': 'Partners', 'job_title': 'Sales Manager', 'city': 'Oxford', 'country_id': 'UK'}, {'first_name': 'Alberto', 'last_name': 'Errazuriz', 'job_title': 'Sales Manager', 'city': 'Oxford', 'country_id': 'UK'}, {'first_name': 'Gerald', 'last_name': 'Cambrault', 'job_title': 'Sales Manager', 'city': 'Oxford', 'country_id': 'UK'}, {'first_name': 'Eleni', 'last_name': 'Zlotkey', 'job_title': 'Sales Manager', 'city': 'Oxford', 'country_id': 'UK'}, {'first_name': 'Peter', 'last_name': 'Tucker', 'job_title': 'Sales Representative', 'city': 'Oxford', 'country_id': 'UK'}, {'fir ...

# %% [markdown]
# # 18. Retrieve the department names along with the count of employees in each department.

# %%
connection = get_connection()
with connection:
    with connection.cursor() as cursor:
        sql = """SELECT d.department_name, COUNT(e.employee_id) AS employee_count
                 FROM departments d
                 LEFT JOIN employees e ON d.department_id = e.department_id
                 GROUP BY d.department_name;
              """
        cursor.execute(sql)
        data = cursor.fetchall()
        print(data)
# Out:
# [{'department_name': 'Administration', 'employee_count': 1}, {'department_name': 'Marketing', 'employee_count': 2}, {'department_name': 'Purchasing', 'employee_count': 6}, {'department_name': 'Human Resources', 'employee_count': 1}, {'department_name': 'Shipping', 'employee_count': 45}, {'department_name': 'IT', 'employee_count': 5}, {'department_name': 'Public Relations', 'employee_count': 1}, {'department_name': 'Sales', 'employee_count': 34}, {'department_name': 'Executive', 'employee_count': 3}, {'department_name': 'Finance', 'employee_count': 6}, {'department_name': 'Accounting', 'employee_count': 2}, {'department_name': 'Treasury', 'employee_count': 0}, {'department_name': 'Corporate Tax', 'employee_count': 0}, {'department_name': 'Control And Credit', 'employee_count': 0}, {'department_name': 'Shareholder Services', 'employee_count': 0}, {'department_name': 'Benefits', 'employee_count': 0}, {'department_name': 'Manufacturing', 'employee_count': 0}, {'department_name': 'Construction', 'employee_count': 0}, {'department_name': 'Contracting', 'employee_count': 0}, {'department_name': 'Operations', 'employee_count': 0}, {'department_name': 'IT Support', 'employee_count': 0}, {'department_name': 'NOC', 'employee_count': 0}, {'department_name': 'IT Helpdesk', 'employee_count': 0}, {'department_name': 'Government Sales', 'employee_count': 0}, {'department_name': 'Retail Sales', 'employee_count': 0}, {'department_name': 'Recruiting', 'employee_count': 0}, {'department_name': 'Payroll', 'employee_count': 0}]

# %% [markdown]
# # 19. Find employees who have the same job as their manager.

# %%
connection = get_connection()
with connection:
    with connection.cursor() as cursor:
        sql = """SELECT e.first_name, e.last_name, j.job_title
                 FROM employees e
                 JOIN employees m ON e.manager_id = m.employee_id
                 JOIN jobs j ON e.job_id = j.job_id
                 WHERE e.job_id = m.job_id;
              """
        cursor.execute(sql)
        data = cursor.fetchall()
        print(data)
# Out:
# [{'first_name': 'Bruce', 'last_name': 'Ernst', 'job_title': 'Programmer'}, {'first_name': 'David', 'last_name': 'Austin', 'job_title': 'Programmer'}, {'first_name': 'Valli', 'last_name': 'Pataballa', 'job_title': 'Programmer'}, {'first_name': 'Diana', 'last_name': 'Lorentz', 'job_title': 'Programmer'}]

# %% [markdown]
# # 20. Display the names of employees who worked in different jobs in the past (use job_history).

# %%
connection = get_connection()
with connection:
    with connection.cursor() as cursor:
        sql = """SELECT DISTINCT e.first_name, e.last_name
                FROM employees e
                JOIN job_history jh ON e.employee_id = jh.employee_id
                WHERE e.job_id != jh.job_id;
              """
        cursor.execute(sql)
        data = cursor.fetchall()
        print(data)
# Out:
# [{'first_name': 'Neena', 'last_name': 'Kochhar'}, {'first_name': 'Jennifer', 'last_name': 'Whalen'}, {'first_name': 'Lex', 'last_name': 'De Haan'}, {'first_name': 'Michael', 'last_name': 'Hartstein'}, {'first_name': 'Jonathon', 'last_name': 'Taylor'}, {'first_name': 'Den', 'last_name': 'Raphaely'}, {'first_name': 'Payam', 'last_name': 'Kaufling'}]
